# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series(["Laptop", "Mobile", "Watch", "Tablet"])

# %%
s1
# Out:
# 0    Laptop
# 1    Mobile
# 2     Watch
# 3    Tablet
# dtype: object

# %%
vlist = ["Laptop", "Mobile", "Watch", "Tablet"]

# %%
print(type(s1))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(vlist))
# Out:
# <class 'list'>

# %%
s1[3]
# Out:
# 'Tablet'

# %% [markdown]
# ## DataFrame

# %%
clist = ["Blue", "Yellow", "Green", "Brown", "Red"]

# %%
clist
# Out:
# ['Blue', 'Yellow', 'Green', 'Brown', 'Red']

# %%
s = pd.Series(clist)

# %%
s.ndim
# Out:
# 1

# %%
df = pd.DataFrame(clist)

# %%
df
# Out:
#         0
# 0    Blue
# 1  Yellow
# 2   Green
# 3   Brown
# 4     Red

# %%
df.ndim
# Out:
# 2

# %%
std = [["john", 10, 56, 75, 80], ["Mary", 10, 56, 75, 80], ["kumar", 10 ,50, 40 ,70], ["sree", 50, 40, 40, 60, 70, 80]]

# %%
std
# Out:
# [['john', 10, 56, 75, 80],
#  ['Mary', 10, 56, 75, 80],
#  ['kumar', 10, 50, 40, 70],
#  ['sree', 50, 40, 40, 60, 70, 80]]

# %%
pd.Series(std)
# Out:
# 0            [john, 10, 56, 75, 80]
# 1            [Mary, 10, 56, 75, 80]
# 2           [kumar, 10, 50, 40, 70]
# 3    [sree, 50, 40, 40, 60, 70, 80]
# dtype: object

# %%
pd.DataFrame(std)
# Out:
#        0   1   2   3   4     5     6
# 0   john  10  56  75  80   NaN   NaN
# 1   Mary  10  56  75  80   NaN   NaN
# 2  kumar  10  50  40  70   NaN   NaN
# 3   sree  50  40  40  60  70.0  80.0

# %%
pd.DataFrame(std, index = ["A", "B", "C", "D"])
# Out:
#        0   1   2   3   4     5     6
# A   john  10  56  75  80   NaN   NaN
# B   Mary  10  56  75  80   NaN   NaN
# C  kumar  10  50  40  70   NaN   NaN
# D   sree  50  40  40  60  70.0  80.0

# %%
dfstd = pd.DataFrame(std, ["A", "B", "C", "D"], columns = ["Name", "class", "English", "physic", "chemistry", "social", "math"] )

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math
# A   john     10       56      75         80     NaN   NaN
# B   Mary     10       56      75         80     NaN   NaN
# C  kumar     10       50      40         70     NaN   NaN
# D   sree     50       40      40         60    70.0  80.0

# %%
dfstd["English"]
# Out:
# A    56
# B    56
# C    50
# D    40
# Name: English, dtype: int64

# %%
type(dfstd["English"])
# Out:
# pandas.core.series.Series

# %%
dfstd.Name
# Out:
# A     john
# B     Mary
# C    kumar
# D     sree
# Name: Name, dtype: object

# %%
dfstd[["Name", "class", "math", "social"]]
# Out:
#     Name  class  math  social
# A   john     10   NaN     NaN
# B   Mary     10   NaN     NaN
# C  kumar     10   NaN     NaN
# D   sree     50  80.0    70.0

# %%
dfstd["class"]
# Out:
# A    10
# B    10
# C    10
# D    50
# Name: class, dtype: int64

# %%
dfstd[["class"]]
# Out:
#    class
# A     10
# B     10
# C     10
# D     50

# %%
type(dfstd[["class"]])
# Out:
# pandas.core.frame.DataFrame

# %%
dfstd.dtypes
# Out:
# Name          object
# class          int64
# English        int64
# physic         int64
# chemistry      int64
# social       float64
# math         float64
# dtype: object

# %%
dfstd.shape
# Out:
# (4, 7)

# %%
dfstd["datascience"] = [75, 59, 62, 80]

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience
# A   john     10       56      75         80     NaN   NaN           75
# B   Mary     10       56      75         80     NaN   NaN           59
# C  kumar     10       50      40         70     NaN   NaN           62
# D   sree     50       40      40         60    70.0  80.0           80

# %%
dfstd["total"] = dfstd["English"] + dfstd["physic"]

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience  total
# A   john     10       56      75         80     NaN   NaN           75    131
# B   Mary     10       56      75         80     NaN   NaN           59    131
# C  kumar     10       50      40         70     NaN   NaN           62     90
# D   sree     50       40      40         60    70.0  80.0           80     80

# %%
dfstd["average"] = dfstd["total"]/6

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience  total  \
# A   john     10       56      75         80     NaN   NaN           75    131
# B   Mary     10       56      75         80     NaN   NaN           59    131
# C  kumar     10       50      40         70     NaN   NaN           62     90
# D   sree     50       40      40         60    70.0  80.0           80     80
#
#      average
# A  21.833333
# B  21.833333
# C  15.000000
# D  13.333333

# %%
dfstd["average"].round(2)
# Out:
# A    21.83
# B    21.83
# C    15.00
# D    13.33
# Name: average, dtype: float64

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience  total  \
# A   john     10       56      75         80     NaN   NaN           75    131
# B   Mary     10       56      75         80     NaN   NaN           59    131
# C  kumar     10       50      40         70     NaN   NaN           62     90
# D   sree     50       40      40         60    70.0  80.0           80     80
#
#      average
# A  21.833333
# B  21.833333
# C  15.000000
# D  13.333333

# %%
dfstd["average"] = np.round(dfstd["average"], 2)

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience  total  \
# A   john     10       56      75         80     NaN   NaN           75    131
# B   Mary     10       56      75         80     NaN   NaN           59    131
# C  kumar     10       50      40         70     NaN   NaN           62     90
# D   sree     50       40      40         60    70.0  80.0           80     80
#
#    average
# A    21.83
# B    21.83
# C    15.00
# D    13.33

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience  total  \
# A   john     10       56      75         80     NaN   NaN           75    131
# B   Mary     10       56      75         80     NaN   NaN           59    131
# C  kumar     10       50      40         70     NaN   NaN           62     90
# D   sree     50       40      40         60    70.0  80.0           80     80
#
#    average
# A    21.83
# B    21.83
# C    15.00
# D    13.33

# %%
import time

# %%
for a in dfstd["average"]:
    print(a)
    time.sleep(1)
# Out:
# 21.83
# 21.83
# 15.0
# 13.33

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience  total  \
# A   john     10       56      75         80     NaN   NaN           75    131
# B   Mary     10       56      75         80     NaN   NaN           59    131
# C  kumar     10       50      40         70     NaN   NaN           62     90
# D   sree     50       40      40         60    70.0  80.0           80     80
#
#    average
# A    21.83
# B    21.83
# C    15.00
# D    13.33

# %%
dfstd["Grade"] = dfstd["average"].map(lambda x: "A" if x >= 20 else "B" if x >=20 and x < 15 else "C")

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience  total  \
# A   john     10       56      75         80     NaN   NaN           75    131
# B   Mary     10       56      75         80     NaN   NaN           59    131
# C  kumar     10       50      40         70     NaN   NaN           62     90
# D   sree     50       40      40         60    70.0  80.0           80     80
#
#    average Grade
# A    21.83     A
# B    21.83     A
# C    15.00     C
# D    13.33     C

# %%
d = pd.date_range(start="25-March-2025", end="5-April-2025", freq="D")

# %%
dfdate = pd.DataFrame(d)

# %%
dfdate
# Out:
#             0
# 0  2025-03-25
# 1  2025-03-26
# 2  2025-03-27
# 3  2025-03-28
# 4  2025-03-29
# 5  2025-03-30
# 6  2025-03-31
# 7  2025-04-01
# 8  2025-04-02
# 9  2025-04-03
# 10 2025-04-04
# 11 2025-04-05

# %%
dfdate
# Out:
#             0
# 0  2025-03-25
# 1  2025-03-26
# 2  2025-03-27
# 3  2025-03-28
# 4  2025-03-29
# 5  2025-03-30
# 6  2025-03-31
# 7  2025-04-01
# 8  2025-04-02
# 9  2025-04-03
# 10 2025-04-04
# 11 2025-04-05

# %%
dfdate = pd.DataFrame(d, columns = ["Date"])

# %%
dfdate
# Out:
#          Date
# 0  2025-03-25
# 1  2025-03-26
# 2  2025-03-27
# 3  2025-03-28
# 4  2025-03-29
# 5  2025-03-30
# 6  2025-03-31
# 7  2025-04-01
# 8  2025-04-02
# 9  2025-04-03
# 10 2025-04-04
# 11 2025-04-05

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience  total  \
# A   john     10       56      75         80     NaN   NaN           75    131
# B   Mary     10       56      75         80     NaN   NaN           59    131
# C  kumar     10       50      40         70     NaN   NaN           62     90
# D   sree     50       40      40         60    70.0  80.0           80     80
#
#    average Grade
# A    21.83     A
# B    21.83     A
# C    15.00     C
# D    13.33     C

# %%
dfyear = dfdate["Date"].dt.year

# %%
dfyear
# Out:
# 0     2025
# 1     2025
# 2     2025
# 3     2025
# 4     2025
# 5     2025
# 6     2025
# 7     2025
# 8     2025
# 9     2025
# 10    2025
# 11    2025
# Name: Date, dtype: int32

# %%
dfdate["year"] = dfyear

# %%
dfdate
# Out:
#          Date  year
# 0  2025-03-25  2025
# 1  2025-03-26  2025
# 2  2025-03-27  2025
# 3  2025-03-28  2025
# 4  2025-03-29  2025
# 5  2025-03-30  2025
# 6  2025-03-31  2025
# 7  2025-04-01  2025
# 8  2025-04-02  2025
# 9  2025-04-03  2025
# 10 2025-04-04  2025
# 11 2025-04-05  2025

# %%
dfdate
# Out:
#          Date  year
# 0  2025-03-25  2025
# 1  2025-03-26  2025
# 2  2025-03-27  2025
# 3  2025-03-28  2025
# 4  2025-03-29  2025
# 5  2025-03-30  2025
# 6  2025-03-31  2025
# 7  2025-04-01  2025
# 8  2025-04-02  2025
# 9  2025-04-03  2025
# 10 2025-04-04  2025
# 11 2025-04-05  2025

# %%
dfdate["Month_Name"] = dfdate["Date"].dt.month_name()

# %%
dfdate
# Out:
#          Date  year Month_Name
# 0  2025-03-25  2025      March
# 1  2025-03-26  2025      March
# 2  2025-03-27  2025      March
# 3  2025-03-28  2025      March
# 4  2025-03-29  2025      March
# 5  2025-03-30  2025      March
# 6  2025-03-31  2025      March
# 7  2025-04-01  2025      April
# 8  2025-04-02  2025      April
# 9  2025-04-03  2025      April
# 10 2025-04-04  2025      April
# 11 2025-04-05  2025      April

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience  total  \
# A   john     10       56      75         80     NaN   NaN           75    131
# B   Mary     10       56      75         80     NaN   NaN           59    131
# C  kumar     10       50      40         70     NaN   NaN           62     90
# D   sree     50       40      40         60    70.0  80.0           80     80
#
#    average Grade
# A    21.83     A
# B    21.83     A
# C    15.00     C
# D    13.33     C

# %%
dfstd = dfstd.drop("Grade", axis=1)

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  social  math  datascience  total  \
# A   john     10       56      75         80     NaN   NaN           75    131
# B   Mary     10       56      75         80     NaN   NaN           59    131
# C  kumar     10       50      40         70     NaN   NaN           62     90
# D   sree     50       40      40         60    70.0  80.0           80     80
#
#    average
# A    21.83
# B    21.83
# C    15.00
# D    13.33

# %%
dfstd.drop("social", axis=1, inplace = True) # inplace is used to save the changes permantely

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  math  datascience  total  average
# A   john     10       56      75         80   NaN           75    131    21.83
# B   Mary     10       56      75         80   NaN           59    131    21.83
# C  kumar     10       50      40         70   NaN           62     90    15.00
# D   sree     50       40      40         60  80.0           80     80    13.33

# %%
dfstd.drop(["math", "total"], axis=1, inplace = True) # to drop a multiple colums in the table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4096507301.py in <cell line: 0>()
# ----> 1 dfstd.drop(["math", "total"], axis=1, inplace = True) # to drop a multiple colums in the table
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  datascience  average
# A   john     10       56      75         80           75    21.83
# B   Mary     10       56      75         80           59    21.83
# C  kumar     10       50      40         70           62    15.00
# D   sree     50       40      40         60           80    13.33

# %% [markdown]
# # DataFrame Row operations

# %%
dfstd
# Out:
#     Name  class  English  physic  chemistry  datascience  average
# A   john     10       56      75         80           75    21.83
# B   Mary     10       56      75         80           59    21.83
# C  kumar     10       50      40         70           62    15.00
# D   sree     50       40      40         60           80    13.33

# %%
dfstd.iloc[2] # loc is working visible index level and index is working default index level
# Out:
# Name           kumar
# class             10
# English           50
# physic            40
# chemistry         70
# datascience       62
# average         15.0
# Name: C, dtype: object

# %%
dfstd.loc[ "A" : "D" : 1 , "Name" : "physic" : 1 ]  # sliceing operation on rows and columns
# Out:
#     Name  class  English  physic
# A   john     10       56      75
# B   Mary     10       56      75
# C  kumar     10       50      40
# D   sree     50       40      40
