# %% [markdown]
# <a href="https://colab.research.google.com/github/hareeshmlops/data-analysis-with-numpy-pandas/blob/main/pandas_slicing_operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
std = [['john', 10, 56, 75], ['mary', 12, 64, 59], ['kumar', 11, 83, 68], ['Shree', 12, 81, 75], ['Naren', 10, 76,90]]

# %%
std
# Out:
# [['john', 10, 56, 75],
#  ['mary', 12, 64, 59],
#  ['kumar', 11, 83, 68],
#  ['Shree', 12, 81, 75],
#  ['Naren', 10, 76, 90]]

# %%
dfstd = pd.DataFrame(std, columns = ['Name', 'Class', 'Maths', 'Science'])

# %%
dfstd
# Out:
#     Name  Class  Maths  Science
# 0   john     10     56       75
# 1   mary     12     64       59
# 2  kumar     11     83       68
# 3  Shree     12     81       75
# 4  Naren     10     76       90

# %%
dfstd
# Out:
#     Name  Class  Maths  Science
# 0   john     10     56       75
# 1   mary     12     64       59
# 2  kumar     11     83       68
# 3  Shree     12     81       75
# 4  Naren     10     76       90

# %%
dfstd["computer"] = [70,80,50,80,60]

# %%
dfstd
# Out:
#     Name  Class  Maths  Science  computer
# 0   john     10     56       75        70
# 1   mary     12     64       59        80
# 2  kumar     11     83       68        50
# 3  Shree     12     81       75        80
# 4  Naren     10     76       90        60

# %%
dfstd.loc[5] = ["subham", 12, 58,68, 89]

# %%
dfstd
# Out:
#      Name  Class  Maths  Science  computer
# 0    john     10     56       75        70
# 1    mary     12     64       59        80
# 2   kumar     11     83       68        50
# 3   Shree     12     81       75        80
# 4   Naren     10     76       90        60
# 5  subham     12     58       68        89

# %%
dfstd.loc[6] = ["sreeja", 12, 60, 70, 90]

# %%
dfstd
# Out:
#      Name  Class  Maths  Science  computer
# 0    john     10     56       75        70
# 1    mary     12     64       59        80
# 2   kumar     11     83       68        50
# 3   Shree     12     81       75        80
# 4   Naren     10     76       90        60
# 5  subham     12     58       68        89
# 6  sreeja     12     60       70        90

# %%
dfstd
# Out:
#      Name  Class  Maths  Science  computer
# 0    john     10     56       75        70
# 1    mary     12     64       59        80
# 2   kumar     11     83       68        50
# 3   Shree     12     81       75        80
# 4   Naren     10     76       90        60
# 5  subham     12     58       68        89
# 6  sreeja     12     60       70        90

# %%
std1 = [['AA', 10, 70,85,80], ['BB', 12, 40,70,80],['CC', 12,40,70,80], ['DD', 12,40,70,80]]

# %%
dfnew = pd.DataFrame(std1, columns = ['Name', 'Class', 'Maths', 'Science', 'Computer'])

# %%
dfnew
# Out:
#   Name  Class  Maths  Science  Computer
# 0   AA     10     70       85        80
# 1   BB     12     40       70        80
# 2   CC     12     40       70        80
# 3   DD     12     40       70        80

# %%
dfstd = pd.concat([dfstd, dfnew])

# %%
dfstd
# Out:
#      Name  Class  Maths  Science  computer  Computer
# 0    john     10     56       75      70.0       NaN
# 1    mary     12     64       59      80.0       NaN
# 2   kumar     11     83       68      50.0       NaN
# 3   Shree     12     81       75      80.0       NaN
# 4   Naren     10     76       90      60.0       NaN
# 5  subham     12     58       68      89.0       NaN
# 6  sreeja     12     60       70      90.0       NaN
# 0      AA     10     70       85       NaN      80.0
# 1      BB     12     40       70       NaN      80.0
# 2      CC     12     40       70       NaN      80.0
# 3      DD     12     40       70       NaN      80.0

# %%
dfstd.iloc[9]
# Out:
# Name          CC
# Class         12
# Maths         40
# Science       70
# computer     NaN
# Computer    80.0
# Name: 2, dtype: object

# %%
dfstd
# Out:
#      Name  Class  Maths  Science  computer  Computer
# 0    john     10     56       75      70.0       NaN
# 1    mary     12     64       59      80.0       NaN
# 2   kumar     11     83       68      50.0       NaN
# 3   Shree     12     81       75      80.0       NaN
# 4   Naren     10     76       90      60.0       NaN
# 5  subham     12     58       68      89.0       NaN
# 6  sreeja     12     60       70      90.0       NaN
# 0      AA     10     70       85       NaN      80.0
# 1      BB     12     40       70       NaN      80.0
# 2      CC     12     40       70       NaN      80.0
# 3      DD     12     40       70       NaN      80.0

# %%
dfstd.iloc[ 0 : 4 :1]
# Out:
#     Name  Class  Maths  Science  computer  Computer
# 0   john     10     56       75      70.0       NaN
# 1   mary     12     64       59      80.0       NaN
# 2  kumar     11     83       68      50.0       NaN
# 3  Shree     12     81       75      80.0       NaN

# %%
dfnew
# Out:
#   Name  Class  Maths  Science  Computer
# 0   AA     10     70       85        80
# 1   BB     12     40       70        80
# 2   CC     12     40       70        80
# 3   DD     12     40       70        80

# %%
pd.concat([dfstd.iloc[ 0 : 4 :1], dfnew, dfstd.iloc[4 : : 1]])
# Out:
#      Name  Class  Maths  Science  computer  Computer
# 0    john     10     56       75      70.0       NaN
# 1    mary     12     64       59      80.0       NaN
# 2   kumar     11     83       68      50.0       NaN
# 3   Shree     12     81       75      80.0       NaN
# 0      AA     10     70       85       NaN      80.0
# 1      BB     12     40       70       NaN      80.0
# 2      CC     12     40       70       NaN      80.0
# 3      DD     12     40       70       NaN      80.0
# 4   Naren     10     76       90      60.0       NaN
# 5  subham     12     58       68      89.0       NaN
# 6  sreeja     12     60       70      90.0       NaN
# 0      AA     10     70       85       NaN      80.0
# 1      BB     12     40       70       NaN      80.0
# 2      CC     12     40       70       NaN      80.0
# 3      DD     12     40       70       NaN      80.0

# %%
dfstd1 = pd.concat([dfstd.iloc[ 0 : 4 :1], dfnew, dfstd.iloc[4 : : 1]])

# %%
dfstd1
# Out:
#      Name  Class  Maths  Science  computer  Computer
# 0    john     10     56       75      70.0       NaN
# 1    mary     12     64       59      80.0       NaN
# 2   kumar     11     83       68      50.0       NaN
# 3   Shree     12     81       75      80.0       NaN
# 0      AA     10     70       85       NaN      80.0
# 1      BB     12     40       70       NaN      80.0
# 2      CC     12     40       70       NaN      80.0
# 3      DD     12     40       70       NaN      80.0
# 4   Naren     10     76       90      60.0       NaN
# 5  subham     12     58       68      89.0       NaN
# 6  sreeja     12     60       70      90.0       NaN
# 0      AA     10     70       85       NaN      80.0
# 1      BB     12     40       70       NaN      80.0
# 2      CC     12     40       70       NaN      80.0
# 3      DD     12     40       70       NaN      80.0

# %% [markdown]
# # Reset index --> it will reset the existing index to default index

# %%
dfstd1 = dfstd1.reset_index() # reset index

# %%
dfstd1 = dfstd1.drop('index', axis = 1)

# %%
dfstd1
# Out:
#       Name  Class  Maths  Science  computer  Computer
# 0     john     10     56       75      70.0       NaN
# 1     mary     12     64       59      80.0       NaN
# 2    kumar     11     83       68      50.0       NaN
# 3    Shree     12     81       75      80.0       NaN
# 4       AA     10     70       85       NaN      80.0
# 5       BB     12     40       70       NaN      80.0
# 6       CC     12     40       70       NaN      80.0
# 7       DD     12     40       70       NaN      80.0
# 8    Naren     10     76       90      60.0       NaN
# 9   subham     12     58       68      89.0       NaN
# 10  sreeja     12     60       70      90.0       NaN
# 11      AA     10     70       85       NaN      80.0
# 12      BB     12     40       70       NaN      80.0
# 13      CC     12     40       70       NaN      80.0
# 14      DD     12     40       70       NaN      80.0

# %%
dfstd1["computer"].max() # to find a max in a single row
# Out:
# 90.0
